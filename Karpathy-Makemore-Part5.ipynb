# %% [markdown]
# ***Token Embedding Lookup Table***

# %%
import numpy as np

def token_embedding_lookup(vocab_size: int, embed_dim: int, token_ids: list, seed: int = 0) -> list:
    """
    Build a random embedding table of shape (vocab_size, embed_dim) using
    np.random.default_rng(seed).standard_normal(...), then return the rows
    corresponding to token_ids as a nested list.
    """
    pass

# %% [markdown]
# ***Implement a Sequential Container for Neural Network Layers***

# %%
import numpy as np

class Sequential:
    """Ordered container of layers with a flat parameters() view."""
    def __init__(self, layers):
        pass

    def __call__(self, x):
        pass

    def parameters(self):
        pass

# %% [markdown]
# ***MLP Character-Level Language Model Forward Pass***

# %%
import numpy as np

def mlp_forward_loss(X, Y, C, W1, b1, W2, b2):
	"""
	Forward pass of an MLP character-level language model.
	Returns mean cross-entropy loss as a float.
	"""
	pass

# %% [markdown]
# ***Implement FlattenConsecutive Layer for Hierarchical Fusion***

# %%
import numpy as np

def flatten_consecutive(x: np.ndarray, n: int) -> np.ndarray:
    """
    Group every n consecutive time steps and fuse them into the channel dim.

    Args:
        x: input array of shape (B, T, C), with T divisible by n.
        n: group size.

    Returns:
        Array of shape (B, T//n, C*n), or (B, C*n) if T//n == 1.
    """
    pass

# %% [markdown]
# ***BatchNorm1d Supporting 2D and 3D Inputs***

# %%
import numpy as np

def batchnorm1d(x, gamma, beta, running_mean, running_var, training=True, momentum=0.1, eps=1e-5):
    """
    BatchNorm1d supporting 2D (N, C) and 3D (N, L, C) inputs.

    Returns a dict with keys 'out', 'running_mean', 'running_var'.
    """
    pass

# %% [markdown]
# ***Sample from MLP Character Language Model***

# %%
import numpy as np

def sample_mlp_lm(C, W1, b1, W2, b2, block_size, itos, seed, max_tokens):
	
	pass
